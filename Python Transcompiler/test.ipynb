# %%
import ast

file=open("./Test_code.py","r").read()
tree=ast.parse(file)
print(ast.dump(tree,indent=4))
# Out:
# Module(
#     body=[
#         AnnAssign(
#             target=Name(id='x', ctx=Store()),
#             annotation=Name(id='float', ctx=Load()),
#             value=BinOp(
#                 left=Constant(value=10),
#                 op=Add(),
#                 right=Constant(value=5)),
#             simple=1),
#         Assign(
#             targets=[
#                 Name(id='y', ctx=Store())],
#             value=BinOp(
#                 left=Constant(value=10),
#                 op=Sub(),
#                 right=Constant(value=5))),
#         Assign(
#             targets=[
#                 Name(id='z', ctx=Store())],
#             value=BinOp(
#                 left=Constant(value=10),
#                 op=Mult(),
#                 right=Constant(value=5))),
#         Assign(
#             targets=[
#                 Name(id='a', ctx=Store())],
#             value=BinOp(
#                 left=Constant(value=10),
#                 op=Div(),
# ...
