# %%
import libcst as cst
import pathlib

from CParser import CParser
base= pathlib.Path("/home/the13bit/miniproject/mini")

file= open(str(base)+"/tst.py", "r").read()

tree=cst.parse_module(file)
print(tree)
# Out:
# Module(
#     body=[
#         SimpleStatementLine(
#             body=[
#                 ImportFrom(
#                     module=Name(
#                         value='typing',
#                         lpar=[],
#                         rpar=[],
#                     ),
#                     names=[
#                         ImportAlias(
#                             name=Name(
#                                 value='List',
#                                 lpar=[],
#                                 rpar=[],
#                             ),
#                             asname=None,
#                             comma=MaybeSentinel.DEFAULT,
#                         ),
#                     ],
#                     relative=[],
#                     lpar=None,
#                     rpar=None,
#                     semicolon=MaybeSentinel.DEFAULT,
#                     whitespace_after_from=SimpleWhitespace(
#                         value=' ',
#                     ),
# ...
